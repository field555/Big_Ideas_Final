# %% [markdown]
# ### Arrests (2016-2022)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Police Arrests.csv")
df
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0      1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1      1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2      1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3      1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4      1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# ...        ...       ...   ...    ...  ...                  ...
# 54727  2046743  22044524  46.0      M    W  2022-03-30T11:45:00
# 54728  2046744  22044562  36.0      F    W  2022-03-26T15:15:00
# 54729  2046745  22044616  27.0      M    B  2022-03-25T18:31:00
# 54730  2046746  22043122  38.0      M    W  2022-03-26T06:55:00
# 54731  2046747  22043238  29.0      M    B  2022-03-23T15:35:00
#
#                                          ARRESTLOCATION  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205
# ...

# %%
df = pd.read_csv("Police Arrests.csv")
df = df.drop(["PK","CCR","RACE","ARRESTTIME","ARRESTLOCATION","INCIDENTZONE","INCIDENTTRACT","COUNCIL_DISTRICT","PUBLIC_WORKS_DIVISION","X","Y"],axis=1)
df.head(10)
# Out:
#     AGE GENDER                                           OFFENSES  \
# 0  42.0      F                                 3929 Retail Theft.
# 1  31.0      M       13(a)(16) Possession of Controlled Substance
# 2  63.0      F                                 3929 Retail Theft.
# 3  25.0      F  5503 Disorderly Conduct. / 5505 Public Drunken...
# 4  25.0      M  2702 Aggravated Assault. / 2705 Recklessy Enda...
# 5  45.0      M                                 3929 Retail Theft.
# 6  29.0      M                               2701 Simple Assault.
# 7  21.0      F  2701 Simple Assault. / 5505 Public Drunkenness...
# 8  17.0      M           903 Criminal Conspiracy. / 3701 Robbery.
# 9  14.0      M  3127 Indecent Exposure. / 3123(a)(6) IDSI with...
#
#                                    INCIDENTLOCATION INCIDENTNEIGHBORHOOD
# 0         4700 Block Centre AV Pittsburgh, PA 15213           Bloomfield
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205         Outside City
# ...

# %%
df = pd.read_csv("Police Arrests.csv")
df = df.drop(["PK","CCR","RACE","ARRESTTIME","ARRESTLOCATION","INCIDENTZONE","INCIDENTTRACT","COUNCIL_DISTRICT","PUBLIC_WORKS_DIVISION","X","Y"],axis=1)
modified = df.drop(["AGE","GENDER","OFFENSES","INCIDENTLOCATION"],axis=1)
modified.value_counts()
# Out:
# INCIDENTNEIGHBORHOOD
# Central Business District    3327
# South Side Flats             2858
# Carrick                      1966
# East Allegheny               1781
# Homewood South               1747
#                              ...
# Regent Square                  28
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Length: 98, dtype: int64

# %%
df = pd.read_csv("Police Arrests.csv")
df = df.drop(["PK","CCR","RACE","ARRESTTIME","ARRESTLOCATION","INCIDENTZONE","INCIDENTTRACT","COUNCIL_DISTRICT","PUBLIC_WORKS_DIVISION","X","Y"],axis=1)
modified = df.drop(["AGE","GENDER","OFFENSES","INCIDENTLOCATION"],axis=1)
modified[["INCIDENTNEIGHBORHOOD"]].value_counts().plot(kind='bar')

# %%
df = pd.read_csv("Police Arrests.csv").drop(["PK","CCR","RACE","ARRESTTIME","ARRESTLOCATION","INCIDENTZONE","INCIDENTTRACT","COUNCIL_DISTRICT","PUBLIC_WORKS_DIVISION","X","Y"],axis=1)
modified = df.drop(["AGE","GENDER","OFFENSES","INCIDENTLOCATION"],axis=1)
last_50=modified.tail(100)
last_50.value_counts().plot(kind='bar')# Put last 50 neighborhoods (Look up)

# %% [markdown]
# ## So the top 5 would be
# 1. Regent Square                  - 28
# 2. Central Northside              - 23
# 3. Mt. Oliver Boro                - 18
# 4. Troy Hill-Herrs Island          - 6
# 5. Mt. Oliver Neighborhood         - 2
